# %%
import os
import pandas as pd
from pandasai import Agent
from pandasai.llm.openai import OpenAI

# Sample DataFrame
sales_by_country = pd.DataFrame({
    "country": ["United States", "United Kingdom", "France", "Germany", "Italy", "Spain", "Canada", "Australia", "Japan", "China"],
    "revenue": [5000, 3200, 2900, 4100, 2300, 2100, 2500, 2600, 4500, 7000]
})

# By default, unless you choose a different LLM, it will use BambooLLM.
# You can get your free API key signing up at https://pandabi.ai (you can also configure it in your .env file)
os.environ["PANDASAI_API_KEY"] = "$2a$10$XnLj/o8hPDZNSg9FKMchse4as6Zgqa0o9J4WTD9hoBZRwtFmyDh3m"
llm = OpenAI(api_token=os.getenv("OPEANI_API_KEY"))

agent = Agent(sales_by_country,  config={"llm": llm})
agent.chat('Which are the top 5 countries by sales?')
# Out:
# 'The top 5 countries by sales are: China, United States, Japan, Germany, United Kingdom'

# %%
agent.chat(
    "What is the total sales for the top 3 countries by sales?"
)
# Out:
# 11100

# %%
agent.chat(
    "Plot the histogram of countries showing for each one the gd. Use different colors for each bar",
)
# Out:
# Traceback (most recent call last):
#   File "/Users/cailynyong/intermediate-1/venv/lib/python3.10/site-packages/pandasai/pipelines/chat/generate_chat_pipeline.py", line 335, in run
#     ).run(input)
#   File "/Users/cailynyong/intermediate-1/venv/lib/python3.10/site-packages/pandasai/pipelines/pipeline.py", line 137, in run
#     raise e
#   File "/Users/cailynyong/intermediate-1/venv/lib/python3.10/site-packages/pandasai/pipelines/pipeline.py", line 101, in run
#     step_output = logic.execute(
#   File "/Users/cailynyong/intermediate-1/venv/lib/python3.10/site-packages/pandasai/pipelines/chat/code_execution.py", line 133, in execute
#     {"content_type": "response", "value": ResponseSerializer.serialize(result)},
#   File "/Users/cailynyong/intermediate-1/venv/lib/python3.10/site-packages/pandasai/responses/response_serializer.py", line 35, in serialize
#     with open(result["value"], "rb") as image_file:
# ...

# %%
import os
import pandas as pd
from pandasai import Agent

employees_data = {
    'EmployeeID': [1, 2, 3, 4, 5],
    'Name': ['John', 'Emma', 'Liam', 'Olivia', 'William'],
    'Department': ['HR', 'Sales', 'IT', 'Marketing', 'Finance']
}

salaries_data = {
    'EmployeeID': [1, 2, 3, 4, 5],
    'Salary': [5000, 6000, 4500, 7000, 5500]
}

employees_df = pd.DataFrame(employees_data)
salaries_df = pd.DataFrame(salaries_data)

# By default, unless you choose a different LLM, it will use BambooLLM.
# You can get your free API key signing up at https://pandabi.ai (you can also configure it in your .env file)
os.environ["PANDASAI_API_KEY"] = "$2a$10$XnLj/o8hPDZNSg9FKMchse4as6Zgqa0o9J4WTD9hoBZRwtFmyDh3m"

agent = Agent([employees_df, salaries_df])
result = agent.chat("Who gets paid the most?")

print(result)
# Out:
# The employee with the highest salary is Olivia with a salary of $7000.
